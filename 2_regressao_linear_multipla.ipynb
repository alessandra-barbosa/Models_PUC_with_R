# %% [markdown]
# # Regressão Linear Multipla_

# %%
getwd() # visualiza a pasta de trabalho do R

setwd("C:\\Users\\alessandra\\Repos\\Models_PUC_with_R\\Datasets") # direciona o R para pasta

getwd() # visualiza a pasta de trabalho do R.home

dados2 <- read.csv2("Regress_ex2.csv") # Leitura do arquivo csv no R
dados2
# Out:
# [1] "C:/Users/Alessandra/Repos/Models_PUC_with_R"
# [1] "C:/Users/alessandra/Repos/Models_PUC_with_R/Datasets"
#    ID y     x1 x2
# 1   1  9.95  2  50
# 2   2 24.45  8 110
# 3   3 31.75 11 120
# 4   4 35.00 10 550
# 5   5 25.02  8 295
# 6   6 16.86  4 200
# 7   7 14.38  2 375
# 8   8  9.60  2  52
# 9   9 24.35  9 100
# 10 10 27.50  8 300
# 11 11 17.08  4 412
# 12 12 37.00 11 400
# 13 13 41.95 12 500
# 14 14 11.66  2 360
# 15 15 21.65  4 205
# 16 16 17.89  4 400
# 17 17 69.00 20 600
# 18 18 10.30  1 585
# 19 19 34.93 10 540
# 20 20 46.59 15 250
# 21 21 44.88 15 290
# 22 22 54.12 16 510
# 23 23 56.63 17 590
# 24 24 22.13  6 100
# 25 25 21.15  5 400

# %%
modelo2 <- lm(dados2$y~dados2$x1+dados2$x2,dados2)
modelo2
# Out:
# Call:
# lm(formula = dados2$y ~ dados2$x1 + dados2$x2, data = dados2)
#
# Coefficients:
# (Intercept)    dados2$x1    dados2$x2
#     2.26379      2.74427      0.01253

# %%
summary(modelo2) #Resultado do modelo de regressão no R
# Out:
# Call:
# lm(formula = dados2$y ~ dados2$x1 + dados2$x2, data = dados2)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -3.865 -1.542 -0.362  1.196  5.841
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.263791   1.060066   2.136 0.044099 *
# dados2$x1   2.744270   0.093524  29.343  < 2e-16 ***
# dados2$x2   0.012528   0.002798   4.477 0.000188 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.288 on 22 degrees of freedom
# Multiple R-squared:  0.9811,	Adjusted R-squared:  0.9794
# F-statistic: 572.2 on 2 and 22 DF,  p-value: < 2.2e-16

# %%
plot(modelo2) # gráficos de resíduos no R
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
