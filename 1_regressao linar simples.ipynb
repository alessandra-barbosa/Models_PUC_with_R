# %% [markdown]
# # Regressão Linear Simples

# %%
getwd() # visualiza a pasta de trabalho do R

setwd("C:\\Users\\alessandra\\Repos\\Models_PUC_with_R\\Datasets") # direciona o R para pasta

getwd() # visualiza a pasta de trabalho do R

dados1 <- read.csv("correl_ex1.csv") # Leitura do arquivo csv no R
dados1
# Out:
# [1] "C:/Users/Alessandra/Repos/Models_PUC_with_R"
# [1] "C:/Users/alessandra/Repos/Models_PUC_with_R/Datasets"
#    Semana comerciais vendas
# 1   1     2          50
# 2   2     5          57
# 3   3     1          41
# 4   4     3          54
# 5   5     4          54
# 6   6     1          38
# 7   7     5          63
# 8   8     3          48
# 9   9     4          59
# 10 10     2          46

# %%
summary(dados1$vendas) # Estatistica descritiva no R

summary(dados1$comerciais) # Estatistica descritiva R
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   38.00   46.50   52.00   51.00   56.25   63.00
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1       2       3       3       4       5

# %%
hist(dados1$comerciais) # histograma no R
# Out:
# Plot with title "Histogram of dados1$comerciais"

# %%
hist(dados1$vendas) # histograma no R.home
# Out:
# Plot with title "Histogram of dados1$vendas"

# %%
plot(dados1$vendas,dados1$comerciais) # gráfico de dispersão no R
# Out:
# plot without title

# %%
cor(dados1$comerciais,dados1$vendas) #correlação de Pearson no R
# Out:
# [1] 0.9304906

# %%
cor.test(dados1$comerciais,dados1$vendas) # teste da correlação de Pearson no R
# Out:
# 	Pearson's product-moment correlation
#
# data:  dados1$comerciais and dados1$vendas
# t = 7.1846, df = 8, p-value = 9.386e-05
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.7264820 0.9837663
# sample estimates:
#       cor
# 0.9304906

# %%
modelo1 <- lm(dados1$vendas~dados1$comerciais,dados1) # ajuste do modelo de regressão no R

# %%
summary(modelo1) #Resultado do modelo de regressão no R
# Out:
# Call:
# lm(formula = dados1$vendas ~ dados1$comerciais, data = dados1)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -3.900 -2.737 -0.075  2.775  3.950
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)         36.150      2.285  15.820 2.55e-07 ***
# dados1$comerciais    4.950      0.689   7.185 9.39e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.081 on 8 degrees of freedom
# Multiple R-squared:  0.8658,	Adjusted R-squared:  0.849
# F-statistic: 51.62 on 1 and 8 DF,  p-value: 9.386e-05

# %%
plot(modelo1) # gráficos de resíduos no R.home
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
