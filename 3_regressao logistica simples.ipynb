# %% [markdown]
# # Regressão Logistica Simples

# %%
getwd() # visualiza a pasta de trabalho do R

setwd("C:\\Users\\alessandra\\Repos\\Models_PUC_with_R\\Datasets") # direciona o R para pasta

getwd() # visualiza a pasta de trabalho do R

Dados <- read.csv2("Dados Titanic -  IA.csv")
Dados
# Out:
# [1] "C:/Users/alessandra/Repos/Models_PUC_with_R/Datasets"
# [1] "C:/Users/alessandra/Repos/Models_PUC_with_R/Datasets"
#     Passageiro Sobrevivente Classe
# 1    1         0            3
# 2    2         1            1
# 3    3         1            3
# 4    4         1            1
# 5    5         0            3
# 6    7         0            1
# 7    8         0            3
# 8    9         1            3
# 9   10         1            2
# 10  11         1            3
# 11  12         1            1
# 12  13         0            3
# 13  14         0            3
# 14  15         0            3
# 15  16         1            2
# 16  17         0            3
# 17  19         0            3
# 18  21         0            2
# 19  22         1            2
# 20  23         1            3
# 21  24         1            1
# 22  25         0            3
# 23  26         1            3
# 24  28         0            1
# 25  31         0            1
# 26  34         0            2
# 27  35         0            1
# 28  36         0            1
# 29  38         0            3
# 30  39         0            3
# ... ...        ...          ...
# 861 NA         NA           NA
# 862 NA         NA           NA
# 863 NA         NA           NA
# 864 NA         NA           NA
# 865 NA         NA           NA
# 866 NA         NA           NA
# 867 NA         NA           NA
# 868 NA         NA           NA
# 869 NA         NA           NA
# 870 NA         NA           NA
# 871 NA         NA           NA
# 872 NA         NA           NA
# 873 NA         NA           NA
# 874 NA         NA           NA
# 875 NA         NA           NA
# 876 NA         NA           NA
# 877 NA         NA           NA
# 878 NA         NA           NA
# 879 NA         NA           NA
# 880 NA         NA           NA
# 881 NA         NA           NA
# 882 NA         NA           NA
# 883 NA         NA           NA
# 884 NA         NA           NA
# 885 NA         NA           NA
# 886 NA         NA           NA
# 887 NA         NA           NA
# 888 NA         NA           NA
# 889 NA         NA           NA
# 890 NA         NA           NA
#     Nome                                                      Sexo      Idade
# 1   Braund, Mr. Owen Harris                                   masculino 22
# 2   Cumings, Mrs. John Bradley (Florence Briggs Thayer)       feminino  38
# 3   Heikkinen, Miss. Laina                                    feminino  26
# 4   Futrelle, Mrs. Jacques Heath (Lily May Peel)              feminino  35
# 5   Allen, Mr. William Henry                                  masculino 35
# 6   McCarthy, Mr. Timothy J                                   masculino 54
# 7   Palsson, Master. Gosta Leonard                            masculino  2
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         feminino  27
# 9   Nasser, Mrs. Nicholas (Adele Achem)                       feminino  14
# 10  Sandstrom, Miss. Marguerite Rut                           feminino   4
# 11  Bonnell, Miss. Elizabeth                                  feminino  58
# 12  Saundercock, Mr. William Henry                            masculino 20
# 13  Andersson, Mr. Anders Johan                               masculino 39
# 14  Vestrom, Miss. Hulda Amanda Adolfina                      feminino  14
# 15  Hewlett, Mrs. (Mary D Kingcome)                           feminino  55
# 16  Rice, Master. Eugene                                      masculino  2
# 17  Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)   feminino  31
# 18  Fynney, Mr. Joseph J                                      masculino 35
# 19  Beesley, Mr. Lawrence                                     masculino 34
# 20  McGowan, Miss. Anna "Annie"                               feminino  15
# 21  Sloper, Mr. William Thompson                              masculino 28
# 22  Palsson, Miss. Torborg Danira                             feminino   8
# 23  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson) feminino  38
# 24  Fortune, Mr. Charles Alexander                            masculino 19
# 25  Uruchurtu, Don. Manuel E                                  masculino 40
# 26  Wheadon, Mr. Edward H                                     masculino 66
# 27  Meyer, Mr. Edgar Joseph                                   masculino 28
# 28  Holverson, Mr. Alexander Oskar                            masculino 42
# 29  Cann, Mr. Ernest Charles                                  masculino 21
# 30  Vander Planke, Miss. Augusta Maria                        feminino  18
# ... ...                                                       ...       ...
# 861                                                                     NA
# 862                                                                     NA
# 863                                                                     NA
# 864                                                                     NA
# 865                                                                     NA
# 866                                                                     NA
# 867                                                                     NA
# 868                                                                     NA
# 869                                                                     NA
# 870                                                                     NA
# 871                                                                     NA
# 872                                                                     NA
# 873                                                                     NA
# 874                                                                     NA
# 875                                                                     NA
# 876                                                                     NA
# 877                                                                     NA
# 878                                                                     NA
# 879                                                                     NA
# 880                                                                     NA
# 881                                                                     NA
# 882                                                                     NA
# 883                                                                     NA
# 884                                                                     NA
# 885                                                                     NA
# 886                                                                     NA
# 887                                                                     NA
# 888                                                                     NA
# 889                                                                     NA
# 890                                                                     NA
#     Irmãos Pais Tarifa
# 1   1      0    7,25
# 2   1      0    712.833
# 3   0      0    7.925
# 4   1      0    53,1
# 5   0      0    8,05
# 6   0      0    518.625
# 7   3      1    21.075
# 8   0      2    111.333
# 9   1      0    300.708
# 10  1      1    16,7
# 11  0      0    26,55
# 12  0      0    8,05
# 13  1      5    31.275
# 14  0      0    78.542
# 15  0      0    16
# 16  4      1    29.125
# 17  1      0    18
# 18  0      0    26
# 19  0      0    13
# 20  0      0    80.292
# 21  0      0    35,5
# 22  3      1    21.075
# 23  1      5    313.875
# 24  3      2    263
# 25  0      0    277.208
# 26  0      0    10,5
# 27  1      0    821.708
# 28  1      0    52
# 29  0      0    8,05
# 30  2      0    18
# ... ...    ...  ...
# 861 NA     NA
# 862 NA     NA
# 863 NA     NA
# 864 NA     NA
# 865 NA     NA
# 866 NA     NA
# 867 NA     NA
# 868 NA     NA
# 869 NA     NA
# 870 NA     NA
# 871 NA     NA
# 872 NA     NA
# 873 NA     NA
# 874 NA     NA
# 875 NA     NA
# 876 NA     NA
# 877 NA     NA
# 878 NA     NA
# 879 NA     NA
# 880 NA     NA
# 881 NA     NA
# 882 NA     NA
# 883 NA     NA
# 884 NA     NA
# 885 NA     NA
# 886 NA     NA
# 887 NA     NA
# 888 NA     NA
# 889 NA     NA
# 890 NA     NA

# %%
modelo1=glm(Dados$Sobrevivente~Dados$Sexo,family=binomial(link="logit"));modelo1
summary(modelo1)
# Out:
# Call:  glm(formula = Dados$Sobrevivente ~ Dados$Sexo, family = binomial(link = "logit"))
#
# Coefficients:
#         (Intercept)  Dados$Sexomasculino
#               1.124               -2.478
#
# Degrees of Freedom: 713 Total (i.e. Null);  712 Residual
#   (176 observations deleted due to missingness)
# Null Deviance:	    964.5
# Residual Deviance: 750.7 	AIC: 754.7
# Call:
# glm(formula = Dados$Sobrevivente ~ Dados$Sexo, family = binomial(link = "logit"))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6767  -0.6779  -0.6779   0.7501   1.7795
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)           1.1243     0.1439   7.814 5.52e-15 ***
# Dados$Sexomasculino  -2.4778     0.1850 -13.392  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 964.52  on 713  degrees of freedom
# Residual deviance: 750.70  on 712  degrees of freedom
#   (176 observations deleted due to missingness)
# AIC: 754.7
#
# Number of Fisher Scoring iterations: 4

# %%
modelo1$coefficients
odds <- exp(-2.477825)
# Out:
#         (Intercept) Dados$Sexomasculino
#            1.124321           -2.477825

# %%
modelo2=glm(Dados$Sobrevivente~Dados$Idade,family=binomial(link="logit"));modelo2
summary(modelo2)
modelo2$coefficients
# Out:
# Call:  glm(formula = Dados$Sobrevivente ~ Dados$Idade, family = binomial(link = "logit"))
#
# Coefficients:
# (Intercept)  Dados$Idade
#    -0.05672     -0.01096
#
# Degrees of Freedom: 713 Total (i.e. Null);  712 Residual
#   (176 observations deleted due to missingness)
# Null Deviance:	    964.5
# Residual Deviance: 960.2 	AIC: 964.2
# Call:
# glm(formula = Dados$Sobrevivente ~ Dados$Idade, family = binomial(link = "logit"))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.1488  -1.0361  -0.9544   1.3159   1.5908
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept) -0.05672    0.17358  -0.327   0.7438
# Dados$Idade -0.01096    0.00533  -2.057   0.0397 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 964.52  on 713  degrees of freedom
# Residual deviance: 960.23  on 712  degrees of freedom
#   (176 observations deleted due to missingness)
# AIC: 964.23
#
# Number of Fisher Scoring iterations: 4
# (Intercept) Dados$Idade
# -0.05672364 -0.01096345

# %%
modelo3=glm(Dados$Sobrevivente~Dados$Classe,family=binomial(link="logit"));modelo3
summary(modelo3)
modelo3$coefficients
# Out:
# Call:  glm(formula = Dados$Sobrevivente ~ Dados$Classe, family = binomial(link = "logit"))
#
# Coefficients:
#  (Intercept)  Dados$Classe
#        1.621        -0.912
#
# Degrees of Freedom: 713 Total (i.e. Null);  712 Residual
#   (176 observations deleted due to missingness)
# Null Deviance:	    964.5
# Residual Deviance: 870.7 	AIC: 874.7
# Call:
# glm(formula = Dados$Sobrevivente ~ Dados$Classe, family = binomial(link = "logit"))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4892  -0.7530  -0.7530   0.8948   1.6727
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)   1.62053    0.22852   7.091 1.33e-12 ***
# Dados$Classe -0.91199    0.09854  -9.255  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 964.52  on 713  degrees of freedom
# Residual deviance: 870.73  on 712  degrees of freedom
#   (176 observations deleted due to missingness)
# AIC: 874.73
#
# Number of Fisher Scoring iterations: 4
#  (Intercept) Dados$Classe
#    1.6205282   -0.9119899

# %%
class(Dados$Classe)
Dados$Classecat <- as.factor(Dados$Classe)
class(Dados$Classecat)
# Out:
# [1] "integer"
# [1] "factor"

# %%
modelo4=glm(Dados$Sobrevivente~Dados$Classecat,family=binomial(link="logit"));modelo4
summary(modelo4)
modelo4$coefficients
# Out:
# Call:  glm(formula = Dados$Sobrevivente ~ Dados$Classecat, family = binomial(link = "logit"))
#
# Coefficients:
#      (Intercept)  Dados$Classecat2  Dados$Classecat3
#           0.6451           -0.7261           -1.8009
#
# Degrees of Freedom: 713 Total (i.e. Null);  711 Residual
#   (176 observations deleted due to missingness)
# Null Deviance:	    964.5
# Residual Deviance: 869.8 	AIC: 875.8
# Call:
# glm(formula = Dados$Sobrevivente ~ Dados$Classecat, family = binomial(link = "logit"))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.4607  -0.7399  -0.7399   0.9184   1.6908
#
# Coefficients:
#                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)        0.6451     0.1543   4.180 2.92e-05 ***
# Dados$Classecat2  -0.7261     0.2168  -3.350 0.000808 ***
# Dados$Classecat3  -1.8009     0.1982  -9.086  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 964.52  on 713  degrees of freedom
# Residual deviance: 869.81  on 711  degrees of freedom
#   (176 observations deleted due to missingness)
# AIC: 875.81
#
# Number of Fisher Scoring iterations: 4
#      (Intercept) Dados$Classecat2 Dados$Classecat3
#         0.645138        -0.726107        -1.800909
